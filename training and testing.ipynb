# %%
# %cd /content/drive/MyDrive/NLP/Codes/CS224/CS224NHomeworks/homework3/a3.zip (Unzipped Files)/a3
# %ls
# Out:
# /content/drive/MyDrive/NLP/Codes/CS224/CS224NHomeworks/homework3/a3.zip (Unzipped Files)/a3
# collect_submission.sh  parser_transitions.py  run.py
# data/                  __pycache__/           testing.ipynb
# parser_model.py        results/               utils/

# %% [markdown]
# **A3 Question 2 part c Implementation**<br>
# Check the parser_transition.py file for more details

# %%
# !python parser_transitions.py part_c
# Out:
# SHIFT test passed!
# LEFT-ARC test passed!
# RIGHT-ARC test passed!
# parse test passed!

# %% [markdown]
# **A3 Question 2 part d Implementation**<br>
# Check the parser_transition.py file for more details

# %%
# !python parser_transitions.py part_d
# Out:
# minibatch_parse test passed!

# %% [markdown]
# **Model File testing**

# %%
# !python parser_model.py

# %% [markdown]
# **Running model**

# %%
# !python run.py
# Out:
# ...
# INITIALIZING
# ...
# Loading data...
# took 1.75 seconds
# Building parser...
# took 1.05 seconds
# Loading pretrained embeddings...
# took 2.31 seconds
# Vectorizing data...
# took 1.68 seconds
# Preprocessing training data...
# took 38.79 seconds
# took 0.03 seconds
#
# ...
# TRAINING
# ...
# Epoch 1 out of 10
# 100% 1848/1848 [00:14<00:00, 128.30it/s]
# Average Train Loss: 0.17865670856201288
# Evaluating on dev set
# 1445850it [00:00, 49884298.82it/s]
# - dev UAS: 84.19
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 1848/1848 [00:11<00:00, 155.85it/s]
# Average Train Loss: 0.11355328529637743
# Evaluating on dev set
# 1445850it [00:00, 49929066.09it/s]
# - dev UAS: 86.31
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100% 1848/1848 [00:11<00:00, 158.99it/s]
# Average Train Loss: 0.09983310721677555
# Evaluating on dev set
# 1445850it [00:00, 49734157.04it/s]
# - dev UAS: 87.24
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# ...
